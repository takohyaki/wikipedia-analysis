# %% [markdown]
# <a href="https://colab.research.google.com/github/yokurang/ml-final-llm-model/blob/main/ml_final_project_llm_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploring Large Language Models (LLMs) for Data Search
#
# We investigated the potential of using large language models (LLMs) to enhance our data search capabilities. Several approaches were considered:
#
# 1. **ChatGPT from OpenAI**: While effective, this option involves additional costs.
# 2. **Local Smaller Models**: Limited by our computational resources, this option could restrict performance.
# 3. **Hosted Open-Source Models via Hugging Face**: This provides a balance of cost-efficiency and capability.
#
# Ultimately, we selected MistralAI7b, an open-source model from Hugging Face, specifically fine-tuned for conversational tasks. This model aligns well with our needs, enabling effective training on our documents, such as Wikipedia articles, to optimize search functionality.

# %% [markdown]
# We first install the necessary libraries and environment variables.

# %%
# %%capture
# !pip3 install pyTelegramBotAPI
# !pip3 install requests
# !pip3 install pandas

# %%
from google.colab import userdata
import telebot
import requests

telegram_bot_token = 'TELEGRAM_TOKEN'  # @param {type: "string"}

try:
  TELEGRAM_API_KEY=userdata.get(telegram_bot_token)
  bot = telebot.TeleBot(TELEGRAM_API_KEY)
  bot.get_me()
except userdata.SecretNotFoundError as e:
   print(f'Secret not found\n\nThis expects you to create a secret named {telegram_bot_token} in Colab\n\nMessage botfather on telegram to create a new bot and get that token\n\nStore that in the secrets section on the left side of the notebook (key icon)\n\nName the secret {telegram_bot_token}')
   raise e
except userdata.NotebookAccessError as e:
  print(f'You need to grant this notebook access to the {telegram_bot_token} secret in order for the notebook to access your Telegram Bot on your behalf.')
  raise e
except Exception as e:
  # unknown error
  print(f"There was an unknown error. Ensure you have a secret {telegram_bot_token} stored in Colab and it's a valid key from telegram")
  raise e

# %% [markdown]
# ## Verifying the Environment Variables
#
# Let us verify that our Telegram bot API key is working correctly.

# %%
# Checking that the tele bot is responsive

url = f"https://api.telegram.org/bot{userdata.get(telegram_bot_token)}/getUpdates"
response = requests.get(url)

print("Status Code:", response.status_code)
print("Response Content:", response.content)
# Out:
# Status Code: 200
# Response Content: b'{"ok":true,"result":[]}'

# %%
response = requests.get(url)

print("Status Code:", response.status_code)
print("Response Content:", response.content)
# Out:
# Status Code: 200
# Response Content: b'{"ok":true,"result":[]}'

# %% [markdown]
# Our telegram bot API key is working.
#
# Let us make sure we can load the data set correctly.

# %%
import pandas as pd
import csv
# Loading the data set
qna = pd.read_csv('updated_qns_answers.csv')
qna
# Out:
#                                                question  points  \
# 0      did the people of gibraltar vote to remain pa...      58
# 1      which country uses the franc as its official ...      55
# 2      which of these old communist parties no longe...      52
# 3     a patient has a terminal illness and wants to ...      65
# 4     according to plato, what are the three types o...      55
# ...                                                 ...     ...
# 2568     what are the main areas of focus in andrology?      62
# 2569  what are the main arguments in favor of animal...      51
# 2570  what are the main arguments in favor of neocla...      47
# 2571  what are the main branches of physical geography?      57
# 2572  what are the main causes of global warming acc...      51
#
#                         article  \
# 0                     Gibraltar
# 1                      Currency
# 2     List of communist parties
# 3                Medical ethics
# 4                  The Republic
# ...                         ...
# 2568                  Andrology
# 2569              Animal rights
# 2570     Neoclassical economics
# 2571                  Geography
# 2572             Global warming
#
#                                            nlp_analysis  readability_score  \
# 0     ([('the united kingdom', 'GPE'), ('2002', 'DAT...              62.68
# 1     ([], [(' ', 'dep', 'which'), ('which', 'det', ...              53.88
# 2     ([('communist', 'NORP'), ('today', 'DATE')], [...              69.79
# 3     ([], [('a', 'det', 'patient'), ('patient', 'ns...              66.23
# 4     ([('three', 'CARDINAL')], [('according', 'prep...              71.14
# ...                                                 ...                ...
# 2568  ([], [('what', 'attr', 'are'), ('are', 'ROOT',...              62.34
# 2569  ([], [('what', 'attr', 'are'), ('are', 'ROOT',...              69.79
# 2570  ([], [('what', 'attr', 'are'), ('are', 'ROOT',...              44.41
# 2571  ([], [('what', 'attr', 'are'), ('are', 'ROOT',...              46.44
# 2572  ([], [('what', 'attr', 'are'), ('are', 'ROOT',...              59.30
#
#                                   preprocessed_question     id  \
# 0     people gibraltar vote remain part united kingd...  15222
# 1                    country us franc official currency   2140
# 2               old communist party longer exists today   4402
# 3     patient terminal illness want end life family ...  13938
# 4        according plato three type people society made  13148
# ...                                                 ...    ...
# 2568                          main area focus andrology  11639
# 2569                   main argument favor animal right  27285
# 2570         main argument favor neoclassical economics  18577
# 2571                     main branch physical geography    296
# 2572        main cause global warming according article   7368
#
#                                                     url  \
# 0           https://simple.wikipedia.org/wiki/Gibraltar
# 1            https://simple.wikipedia.org/wiki/Currency
# 2     https://simple.wikipedia.org/wiki/List%20of%20...
# 3     https://simple.wikipedia.org/wiki/Medical%20et...
# 4      https://simple.wikipedia.org/wiki/The%20Republic
# ...                                                 ...
# 2568        https://simple.wikipedia.org/wiki/Andrology
# 2569  https://simple.wikipedia.org/wiki/Animal%20rights
# 2570  https://simple.wikipedia.org/wiki/Neoclassical...
# 2571        https://simple.wikipedia.org/wiki/Geography
# 2572  https://simple.wikipedia.org/wiki/Global%20war...
#
#                                            article_text  \
# 0     Gibraltar is an Overseas Territory of the Unit...
# 1     Currency is the unit of money used by the peop...
# 2     There are a number of communist parties around...
# 3     Medical ethics is the set of ethical rules tha...
# 4     The Republic is a book by Plato. It was finish...
# ...                                                 ...
# 2568  Andrology is the study of male health, especia...
# 2569  Animal rights is a term used for the general b...
# 2570  Neoclassical economics is an economic theory t...
# 2571  Geography (from Greek: , geographia, literally...
# 2572  Global warming is the current rise in temperat...
#
#                                       preprocessed_text  cluster
# 0     gibraltar overseas territory united kingdom me...    192.0
# 1     currency unit money used people country union ...    127.0
# 2     number communist party around world world hist...    121.0
# 3     medical ethic set ethical rule doctor follow i...    117.0
# 4     republic book plato finished bc asks question ...    117.0
# ...                                                 ...      ...
# 2568  andrology study male health especially male se...     22.0
# 2569  animal right term used general belief non huma...    159.0
# 2570  neoclassical economics economic theory argues ...    148.0
# 2571  geography greek geographia literally earth des...    181.0
# 2572  global warming current rise temperature air oc...      NaN
#
# [2573 rows x 11 columns]

# %%
import telebot

# Initialise the Tele Bot

BOT_TOKEN = userdata.get(telegram_bot_token)
bot = telebot.TeleBot(BOT_TOKEN)

# %% [markdown]
# Next let us make sure that we can load the Huggingface API key correctly.

# %%
# @title ⚙️ Configure Hugging Face Token

from google.colab import userdata

hugging_face_token_secret = 'HF_TOKEN'  # @param {type: "string"}

try:
  TELEGRAM_API_KEY=userdata.get(hugging_face_token_secret)
except userdata.SecretNotFoundError as e:
   print(f'Secret not found\n\nThis expects you to create a secret named {hugging_face_token_secret} in Colab\n\nGot to that url and create a write token (https://huggingface.co/settings/tokens)\n\nStore that in the secrets section on the left side of the notebook (key icon)\n\nName the secret {hugging_face_token_secret}')
   raise e
except userdata.NotebookAccessError as e:
  print(f'You need to grant this notebook access to the {hugging_face_token_secret} secret in order for the notebook to access your Telegram Bot on your behalf.')
  raise e
except Exception as e:
  # unknown error
  print(f"There was an unknown error. Ensure you have a secret {hugging_face_token_secret} stored in Colab and it's a valid key from telegram")
  raise e

# %%
# %%capture
# !pip3 install langchain transformers

# %%
import os
from langchain_community.llms import HuggingFaceHub

# Get HuggingFace Credentials

os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get(hugging_face_token_secret)

# %%
from transformers import AutoTokenizer

# %%
# !pip3 install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 22.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.25.2)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.8.0

# %% [markdown]
# ## Setting Up the Web Scraper and Vector Database
#
# To effectively respond to queries with precise context, we've developed a system to process Wikipedia URLs by:
#
# 1. **Loading Webpages**: We begin by loading each Wikipedia URL present in our dataset.
# 2. **Content Extraction**: Next, we extract textual content from these webpages.
# 3. **Content Chunking**: The extracted content is then segmented into manageable chunks, ensuring that each chunk contains a coherent portion of the content.
# 4. **Embedding Chunks**: Each chunk is transformed into embeddings using the `sentence-transformers/all-MiniLM-l6-v2` model from Hugging Face, which provides a high-level representation of the text.
# 5. **FAISS Database**: These embeddings are stored in a FAISS-backed database, which is optimized for efficient similarity-based query matching. This setup allows the database to return only the most relevant content in response to a query.
#
# This architecture leverages the Retriever-Augmented Generation (RAG) technique, enabling the use of our own document corpus as a searchable data layer. By integrating this system with our bot through various LangChain modules, we ensure that our large language model can efficiently navigate and retrieve information from our custom dataset.

# %%
from langchain_community.document_loaders import WebBaseLoader, PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.storage import LocalFileStore
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings
from langchain.embeddings import CacheBackedEmbeddings

# %%
store = LocalFileStore("./cache")
core_embeddings_model = HuggingFaceInferenceAPIEmbeddings(
    api_key = userdata.get(hugging_face_token_secret),
    model_name="sentence-transformers/all-MiniLM-l6-v2")

embedder = CacheBackedEmbeddings.from_bytes_store(core_embeddings_model, store)
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 50, length_function = len)

# %% [markdown]
# We can train our model with a subset of the data since we are limited by our laptop's computational resources.

# %%
def process_urls(urls, text_splitter, embedder):
    all_chunks = []

    # Step 1: Collect chunks from all URLs
    for url in set(urls):  # Ensure uniqueness
        print(f"Processing {url}...")
        content = WebBaseLoader(url).load()
        chunks = text_splitter.transform_documents(content)
        all_chunks.extend(chunks)

    # Step 2 and 3: Process all chunks to generate embeddings and create a single vector store
    vectorstore = FAISS.from_documents(all_chunks, embedder)

    return vectorstore

combined_vectorstore = process_urls(qna['url'][:50], text_splitter, embedder) # modify here
retriever = combined_vectorstore.as_retriever(search_type="similarity_score_threshold", search_kwargs={"score_threshold": 0.3})
# Out:
# Processing https://simple.wikipedia.org/wiki/By-product...
# Processing https://simple.wikipedia.org/wiki/Boy...
# Processing https://simple.wikipedia.org/wiki/Fact...
# Processing https://simple.wikipedia.org/wiki/Newt...
# Processing https://simple.wikipedia.org/wiki/Half-life%20%28element%29...
# Processing https://simple.wikipedia.org/wiki/Buddha...
# Processing https://simple.wikipedia.org/wiki/List%20of%20communist%20parties...
# Processing https://simple.wikipedia.org/wiki/Shetland%20Sheepdog...
# Processing https://simple.wikipedia.org/wiki/Snow%20leopard...
# Processing https://simple.wikipedia.org/wiki/Galician%20language...
# Processing https://simple.wikipedia.org/wiki/Medical%20ethics...
# Processing https://simple.wikipedia.org/wiki/The%20Republic...
# Processing https://simple.wikipedia.org/wiki/Biscuit...
# Processing https://simple.wikipedia.org/wiki/Ketchup...
# Processing https://simple.wikipedia.org/wiki/Election...
# Processing https://simple.wikipedia.org/wiki/Handcuffs...
# Processing https://simple.wikipedia.org/wiki/Time%20dilation...
# Processing https://simple.wikipedia.org/wiki/Golden%20Retriever...
# Processing https://simple.wikipedia.org/wiki/Sock...
# Processing https://simple.wikipedia.org/wiki/Wallet...
# Processing https://simple.wikipedia.org/wiki/Soda...
# Processing https://simple.wikipedia.org/wiki/Point%20%28geometry%29...
# Processing https://simple.wikipedia.org/wiki/Duck...
# Processing https://simple.wikipedia.org/wiki/Gibraltar...
# Processing https://simple.wikipedia.org/wiki/Berry...
# Processing https://simple.wikipedia.org/wiki/Fetishism...
# Processing https://simple.wikipedia.org/wiki/Fruit...
# Processing https://simple.wikipedia.org/wiki/Ferret...
# Processing https://simple.wikipedia.org/wiki/Fly...
# Processing https://simple.wikipedia.org/wiki/Andrology...
# Processing https://simple.wikipedia.org/wiki/Currency...
# Processing https://simple.wikipedia.org/wiki/Pig...
# Processing https://simple.wikipedia.org/wiki/Axiom...
# Processing https://simple.wikipedia.org/wiki/Hard%20science...
# Processing https://simple.wikipedia.org/wiki/Necktie...
# Processing https://simple.wikipedia.org/wiki/Autobahn...
# Processing https://simple.wikipedia.org/wiki/Dyadic...
# Processing https://simple.wikipedia.org/wiki/Cult...
# Processing https://simple.wikipedia.org/wiki/Nut...
# Processing https://simple.wikipedia.org/wiki/Female...
# Processing https://simple.wikipedia.org/wiki/List%20of%20fruits...
# Processing https://simple.wikipedia.org/wiki/Albinism...
# Processing https://simple.wikipedia.org/wiki/Random...
# Processing https://simple.wikipedia.org/wiki/Slavs...
# Processing https://simple.wikipedia.org/wiki/Manx%20cat...
# Processing https://simple.wikipedia.org/wiki/Bun...
# Processing https://simple.wikipedia.org/wiki/Set...
# Processing https://simple.wikipedia.org/wiki/Scissors...
# Processing https://simple.wikipedia.org/wiki/Audio%20cassette...

# %%
# qna[['question','article','url','article_text']]
qna[['question']][:10]
# Out:
#                                             question
# 0   did the people of gibraltar vote to remain pa...
# 1   which country uses the franc as its official ...
# 2   which of these old communist parties no longe...
# 3  a patient has a terminal illness and wants to ...
# 4  according to plato, what are the three types o...
# 5  after ten half-lives, what percentage of the o...
# 6  approximately how many years will pass on eart...
# 7                       are a and b the same number?
# 8  are addition and multiplication dyadic functions?
# 9  are albinic animals more likely to be attacked...

# %%
retriever.get_relevant_documents("a patient has a terminal illness and wants to end their life, but their family members are opposed to it. how should the doctor handle this situation?")
# Out:
# [Document(page_content="If there is not enough of a medicine to treat every person who has a disease who should get the medicine?\nIf a baby has a disease that will kill him very soon, what should a doctor do if the baby's mother says she does not want the baby to be helped?\nA patient has an injury that cannot be helped and that will kill them in a few minutes. The patient asks a doctor “am I going to die?” What should the doctor say?", metadata={'source': 'https://simple.wikipedia.org/wiki/Medical%20ethics', 'title': 'Medical ethics - Simple English Wikipedia, the free encyclopedia', 'language': 'en'})]

# %% [markdown]
# The function below is to extract the content from FAISS database for a given query for our Telegram bot.

# %%
def append_documents_to_instruction(instruction):
    instruction_with_documents = f'''
    Answer the following question, making use of the documents provided below if they are relevant.
    Do not use those documents and do not mention them if you deem that they do not contain any relevant information. Do not mention the id of the documents.
    If a document is relevant, add the source of the information by adding a link to the exact url that was used.
    For that use the 'source' field of the relevant document.
    Question: {instruction}
    '''

    docs = retriever.get_relevant_documents(instruction)

    if len(docs) == 0: # If there are no relevant documents, just return the original instruction
        return instruction

    instruction_with_documents += "Documents:\n"

    for i, doc in enumerate(docs):
        instruction_with_documents += f'''- {doc.metadata}
            Content: {doc.page_content}'''
    return instruction_with_documents

# %% [markdown]
# The following is the LLM class to interact with the MistralAI7b model for the Telegram bot.

# %%
class LLM:
  def __init__(self):
    model_string = "mistralai/Mistral-7B-Instruct-v0.2"
    self.chat = []
    self.llm = HuggingFaceHub(repo_id=model_string, model_kwargs={"temperature": 0.5, "max_length":64,"max_new_tokens":512})
    self.tokenizer = AutoTokenizer.from_pretrained(model_string)

  def get_reply(self, instruction):
    instruction_with_context = append_documents_to_instruction(instruction)
    self.chat.append({"role" : "user", "content" : instruction_with_context})

    prompt = self.tokenizer.apply_chat_template(self.chat, tokenize=False)
    reply = self.llm.invoke(prompt)
    self.chat.append({"role" : "assistant", "content" : reply})
    return reply

# %% [markdown]
# I also added the feature where the Telegram bot can accept PDF files and extract information from them.

# %%
# !pip3 install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf) (4.11.0)
# Installing collected packages: pypdf
# Successfully installed pypdf-4.2.0

# %%
def dl_file(message):
    import requests
    file_info = bot.get_file(message.document.file_id)

    download_url = f"https://api.telegram.org/file/bot{bot.token}/{file_info.file_path}"
    response = requests.get(download_url)

    if response.status_code == 200:
        with open(message.document.file_name, 'wb') as file:
            file.write(response.content)
        return True
    else:
        return False

# %%
def init_bot():
  bot = telebot.TeleBot(BOT_TOKEN)

  @bot.message_handler(commands=['start'])
  def on_start(message):
      bot.send_message(message.chat.id, "Beep, boop, starting bot...")

  @bot.message_handler(commands=['newchat'])
  def on_new_chat(message):
    llm.chat = []
    bot.reply_to(message,  "Starting new chat!")

  @bot.message_handler(content_types=['document'])
  def on_document(message):
    if message.document.mime_type == 'application/pdf':
        reply = bot.reply_to(message, "⬇️ Downloading file ⬇️")

        if not dl_file(message):
            bot.edit_message_text("❌ Failed to download file", reply.chat.id, reply.message_id)
            return

        bot.edit_message_text("🗃️ Adding file to database 🗃️", reply.chat.id, reply.message_id)

        loader = PyPDFLoader(message.document.file_name)
        pages = loader.load_and_split()
        chunks = text_splitter.transform_documents(pages)

        combined_vectorstore.add_documents(chunks)

        bot.edit_message_text("✅ PDF received and added to database", reply.chat.id, reply.message_id)
    else:
        bot.reply_to(message, "For the moment, I only support indexing PDF files. Please send a PDF file.")

  @bot.message_handler(func=lambda msg: True)
  def on_message(message):
      print(f"Message received! {message}")
      reply = llm.get_reply(message.text)
      bot.reply_to(message, reply)

  return bot

# %%
llm = LLM()
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.huggingface_hub.HuggingFaceHub` was deprecated in langchain-community 0.0.21 and will be removed in 0.2.0. Use HuggingFaceEndpoint instead.
#   warn_deprecated(
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %% [markdown]
# ## Starting the Telegram Bot
#
# To activate the Telegram bot, execute the subsequent cell which will keep the bot running indefinitely, ready to respond to user queries. Interaction with the bot is done through the Telegram app. To halt the bot, simply interrupt the running cell.
#
# Due to the potential computational limitations of local machines, it's recommended to run the bot in Google Colab. You can access the appropriate Colab notebook [here](https://colab.research.google.com/drive/1FgZJTcYCAsYMuHCRPTWUQAvEWR4nKoQH?usp=sharing).
#
# **Preparation for Google Colab**:
# Before using Google Colab, ensure you upload the following items:
# - `updated_qns_answers.csv`: The dataset file.
# - `huggingface_api_key`: Your API key for Hugging Face.
# - `telegram_bot_api_key`: Your API key for the Telegram bot.
#
# These steps will prepare your environment to effectively run the Telegram bot without local resource constraints.

# %%
bot = init_bot()
llm.chat = []
bot.infinity_polling()
# Out:
# Message received! {'content_type': 'text', 'id': 44, 'message_id': 44, 'from_user': {'id': 5304133338, 'is_bot': False, 'first_name': 'y', 'username': 'yokurang', 'last_name': 'k', 'language_code': 'en', 'can_join_groups': None, 'can_read_all_group_messages': None, 'supports_inline_queries': None, 'is_premium': None, 'added_to_attachment_menu': None, 'can_connect_to_business': None}, 'date': 1713330416, 'chat': {'id': 5304133338, 'type': 'private', 'title': None, 'username': 'yokurang', 'first_name': 'y', 'last_name': 'k', 'is_forum': None, 'photo': None, 'bio': None, 'join_to_send_messages': None, 'join_by_request': None, 'has_private_forwards': None, 'has_restricted_voice_and_video_messages': None, 'description': None, 'invite_link': None, 'pinned_message': None, 'permissions': None, 'slow_mode_delay': None, 'message_auto_delete_time': None, 'has_protected_content': None, 'sticker_set_name': None, 'can_set_sticker_set': None, 'linked_chat_id': None, 'location': None, 'active_usernames': None, 'emoji_status_custom_emoji_id': None, 'has_hidden_members': None, 'has_aggressive_anti_spam_enabled': None, 'emoji_status_expiration_date': None, 'available_reactions': None, 'accent_color_id': None, 'background_custom_emoji_id': None, 'profile_accent_color_id': None, 'profile_background_custom_emoji_id': None, 'has_visible_history': None, 'unrestrict_boost_count': None, 'custom_emoji_sticker_set_name': None, 'business_intro': None, 'business_location': None, 'business_opening_hours': None, 'personal_chat': None, 'birthdate': None}, 'sender_chat': None, 'is_automatic_forward': None, 'reply_to_message': None, 'via_bot': None, 'edit_date': None, 'has_protected_content': None, 'media_group_id': None, 'author_signature': None, 'text': 'a patient has a terminal illness and wants to end their life, but their family members are opposed to it. how should the doctor handle this situation?', 'entities': None, 'caption_entities': None, 'audio': None, 'document': None, 'photo': None, 'sticker': None, 'video': None, 'video_note': None, 'voice': None, 'caption': None, 'contact': None, 'location': None, 'venue': None, 'animation': None, 'dice': None, 'new_chat_members': None, 'left_chat_member': None, 'new_chat_title': None, 'new_chat_photo': None, 'delete_chat_photo': None, 'group_chat_created': None, 'supergroup_chat_created': None, 'channel_chat_created': None, 'migrate_to_chat_id': None, 'migrate_from_chat_id': None, 'pinned_message': None, 'invoice': None, 'successful_payment': None, 'connected_website': None, 'reply_markup': None, 'message_thread_id': None, 'is_topic_message': None, 'forum_topic_created': None, 'forum_topic_closed': None, 'forum_topic_reopened': None, 'has_media_spoiler': None, 'forum_topic_edited': None, 'general_forum_topic_hidden': None, 'general_forum_topic_unhidden': None, 'write_access_allowed': None, 'users_shared': None, 'chat_shared': None, 'story': None, 'external_reply': None, 'quote': None, 'link_preview_options': None, 'giveaway_created': None, 'giveaway': None, 'giveaway_winners': None, 'giveaway_completed': None, 'forward_origin': None, 'boost_added': None, 'sender_boost_count': None, 'reply_to_story': None, 'sender_business_bot': None, 'business_connection_id': None, 'is_from_offline': None, 'json': {'message_id': 44, 'from': {'id': 5304133338, 'is_bot': False, 'first_name': 'y', 'last_name': 'k', 'username': 'yokurang', 'language_code': 'en'}, 'chat': {'id': 5304133338, 'first_name': 'y', 'last_name': 'k', 'username': 'yokurang', 'type': 'private'}, 'date': 1713330416, 'text': 'a patient has a terminal illness and wants to end their life, but their family members are opposed to it. how should the doctor handle this situation?'}}
# 2024-04-17 05:07:07,100 (__init__.py:1092 MainThread) ERROR - TeleBot: "Infinity polling: polling exited"
# ERROR:TeleBot:Infinity polling: polling exited
# 2024-04-17 05:07:07,104 (__init__.py:1094 MainThread) ERROR - TeleBot: "Break infinity polling"
# ERROR:TeleBot:Break infinity polling

# %% [markdown]
# Let us cross-validate our model.

# %%
qna_asked = []
qs = qna[['question']]
qs
# Out:
#                                                question
# 0      did the people of gibraltar vote to remain pa...
# 1      which country uses the franc as its official ...
# 2      which of these old communist parties no longe...
# 3     a patient has a terminal illness and wants to ...
# 4     according to plato, what are the three types o...
# ...                                                 ...
# 2568     what are the main areas of focus in andrology?
# 2569  what are the main arguments in favor of animal...
# 2570  what are the main arguments in favor of neocla...
# 2571  what are the main branches of physical geography?
# 2572  what are the main causes of global warming acc...
#
# [2573 rows x 1 columns]

# %%
def cross_validate_retriever(questions, retriever):
    qna_asked = []  # Initialize an empty list to store question and metadata
    processed_questions = set()  # Set to track processed questions to avoid duplicates

    # Iterate over each question
    for question in questions:
        # Skip the question if it has already been processed
        if question in processed_questions:
            continue

        # Retrieve relevant documents for the question using the provided retriever
        docs = retriever.get_relevant_documents(question)

        # Store the question and the metadata of each document, and mark the question as processed
        for doc in docs:
            qna_asked.append({'question': question, 'metadata': doc.metadata})
        processed_questions.add(question)

    return qna_asked

# %% [markdown]
# Since we trained on the first 50 questions, let us cross-validate on the first 50 questions too.

# %%
questions = qna['question'][:50]

qna_asked = cross_validate_retriever(questions, retriever)

def remove_duplicates(qna_asked):
    unique_entries_str = set(str(entry) for entry in qna_asked)  # Convert to set of strings to remove duplicates
    unique_qna_asked = [eval(entry) for entry in unique_entries_str]  # Convert back to list of dictionaries
    return unique_qna_asked


qna_asked_filtered = remove_duplicates(qna_asked)
qna_asked_filtered
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/vectorstores.py:330: UserWarning: Relevance scores must be between 0 and 1, got [(Document(page_content='Print/export\n\t\n\n\nMake a bookDownload as PDFPage for printing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFrom Simple English Wikipedia, the free encyclopedia\n\n\nA dyadic is a math function that needs two things in order to give something out.  Addition and multiplication are dyadic.  Powers are also dyadic.  There are many more functions that are dyadic.\nDyadic may specifically refer to:', metadata={'source': 'https://simple.wikipedia.org/wiki/Dyadic', 'title': 'Dyadic - Simple English Wikipedia, the free encyclopedia', 'language': 'en'}), 0.3834098558710256), (Document(page_content='Dyad\nDyadic communication\nDyadic counterpoint, the voice-against-voice conception of polyphony\nDyadic fraction\nDyadic product\nDyadic rational (also known as Dyadic solenoid)\nDyadic Relation (usually known as a Binary relation)\nDyadic tensor\nDyadic transformation\n\n\n\n \n This disambiguation page lists  articles associated with the title Dyadic.  If an internal link led you here, you may wish to change the link to point directly to the intended article.', metadata={'source': 'https://simple.wikipedia.org/wiki/Dyadic', 'title': 'Dyadic - Simple English Wikipedia, the free encyclopedia', 'language': 'en'}), 0.2431734245621211), (Document(page_content='Two numbers that are both the same as a third number are the same number.\nIf A and B are two numbers that are the same, and C and D are also the same, A+C is the same as B+D.\nIf A and B are two numbers that are the same, and C and D are also the same, A-C is the same as B-D.\nTwo shapes that fill exactly the same space are the same shape.\nIf you divide a number by anything more than 1, the quotient (result) will be less than the original number.\nRelated pages[change | change source]', metadata={'source': 'https://simple.wikipedia.org/wiki/Axiom', 'title': 'Axiom - Simple English Wikipedia, the free encyclopedia', 'language': 'en'}), -0.08075705355527085), (Document(page_content='This short article about mathematics can be made longer. You can help Wikipedia by adding to it.\n\n\n\n\nRetrieved from "https://simple.wikipedia.org/w/index.php?title=Axiom&oldid=9028097"\nCategory: MathematicsHidden category: Math stubs\n\n\n\n\n\n\n This page was last changed on 27 August 2023, at 14:23.\nText is available under the Creative Commons Attribution-ShareAlike License and the GFDL; additional terms may apply. See Terms of Use for details.', metadata={'source': 'https://simple.wikipedia.org/wiki/Axiom', 'title': 'Axiom - Simple English Wikipedia, the free encyclopedia', 'language': 'en'}), -0.11717934851402112)]
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain_core/vectorstores.py:342: UserWarning: No relevant docs were retrieved using the relevance score threshold 0.3
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain_core/vectorstores.py:330: UserWarning: Relevance scores must be between 0 and 1, got [(Document(page_content='Men are more susceptible to heart disease than women. They also usually have a slightly shorter natural average life span. However, men get many conditions, such as osteoporosis, less than women.', metadata={'source': 'https://simple.wikipedia.org/wiki/Andrology', 'title': 'Andrology - Simple English Wikipedia, the free encyclopedia', 'language': 'en'}), 0.4983693048414005), (Document(page_content="Andrology is the study of male health, especially male sexual organs and reproduction. \nIt is similar to the study of women's health, called gynaecology. Andrology has only been studied since the late 1960s. The first specialist journal on the subject was the German periodical Andrologie, published from 1969 onwards.[1]", metadata={'source': 'https://simple.wikipedia.org/wiki/Andrology', 'title': 'Andrology - Simple English Wikipedia, the free encyclopedia', 'language': 'en'}), 0.02795475732609176), (Document(page_content="Organisms can either be grouped as male or female. Female humans are called women and their bodies are different from male humans (who are called men). A woman has a vagina between her legs (a male has a penis) which is the main sexual organ.  They also have breasts with milk glands, which allow them to nurse (feed) infants.  A woman's shoulders are usually not as wide as a man's, but women usually have wider hips than men, because they need wide hips to be able to give birth.", metadata={'source': 'https://simple.wikipedia.org/wiki/Female', 'title': 'Female - Simple English Wikipedia, the free encyclopedia', 'language': 'en'}), 0.01984983406374985), (Document(page_content='This article needs more sources for reliability. Please help improve this article by adding reliable sources.  Unsourced material may be challenged or removed.Find sources:\xa0"Female"\xa0–\xa0news\xa0· newspapers\xa0· books\xa0· scholar\xa0· JSTOR (December 2011) (Learn how and when to remove this template message)\nThe symbol biologists use for female organisms\nFemale is one of the two sexes. It is the sex that produces ova ("egg" cells) for sexual reproduction. Females of some species also bear offspring.[1]', metadata={'source': 'https://simple.wikipedia.org/wiki/Female', 'title': 'Female - Simple English Wikipedia, the free encyclopedia', 'language': 'en'}), -0.061802351374466546)]
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain_core/vectorstores.py:330: UserWarning: Relevance scores must be between 0 and 1, got [(Document(page_content='A striped bow tie.\nBow ties[change | change source]\nThe bow tie is a type of necktie. It is a ribbon of fabric tied around the collar in a symmetrical manner such that the two opposite ends form loops. \nReady-tied bow ties are available, in which the distinctive bow is sewn and a band goes around the neck and clips to secure. Some "clip-ons" dispense with the band altogether, instead clipping to the collar. \n\n\n This short article can be made longer. You can help Wikipedia by adding to it.', metadata={'source': 'https://simple.wikipedia.org/wiki/Necktie', 'title': 'Necktie - Simple English Wikipedia, the free encyclopedia', 'language': 'en'}), 0.4510761996867808), (Document(page_content='A tie as usually worn\nTyrone Power with white bow tie\nLloyd George on the left, Winston Churchill on the right, 1907\nA necktie (or a tie) is an article of clothing worn by men. A tie is part of an ensemble (or outfit) of clothing called the "suit and tie." This outfit is worn in Western countries by men in professional jobs such as business, law, and politics.', metadata={'source': 'https://simple.wikipedia.org/wiki/Necktie', 'title': 'Necktie - Simple English Wikipedia, the free encyclopedia', 'language': 'en'}), 0.30672197913151344), (Document(page_content='A necktie is usually made of silk or polyester, and it usually has a color or pattern on it. Men tie a knot in neckties and wear them with dress shirts in order to make them look more formal.', metadata={'source': 'https://simple.wikipedia.org/wiki/Necktie', 'title': 'Necktie - Simple English Wikipedia, the free encyclopedia', 'language': 'en'}), 0.15055513490355232), (Document(page_content='However, this usage means that cheap handcuffs are used in times where steel ones would normally be unused for long times. Recent products have been made that deal with this. These include disposable plastic restraints that can be opened with a key. These are more expensive than traditional plastic restraints, since they can only be used for a small number of times, usually only one, and are not as strong. In addition, many people think plastic restraints are more likely to cause nerve or', metadata={'source': 'https://simple.wikipedia.org/wiki/Handcuffs', 'title': 'Handcuffs - Simple English Wikipedia, the free encyclopedia', 'language': 'en'}), -0.005956681279470466)]
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain_core/vectorstores.py:342: UserWarning: No relevant docs were retrieved using the relevance score threshold 0.3
#   warnings.warn(
# [{'question': 'are cassette tapes still popular among audiophiles?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Audio%20cassette',
#    'title': 'Audio cassette - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are handcuffs used for hog-tying a suspect?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Handcuffs',
#    'title': 'Handcuffs - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are there any cultures or belief systems that attribute supernatural powers to certain objects, such as amulets or talismans, as a form of fetishism?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Fetishism',
#    'title': 'Fetishism - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are shelties considered to be highly energetic dogs?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Shetland%20Sheepdog',
#    'title': 'Shetland Sheepdog - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are biscuits in british english sweet or savory?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Biscuit',
#    'title': 'Biscuit - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are midges and gnats the same thing?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Fly',
#    'title': 'Fly - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'approximately how many years will pass on earth for each year in the spaceship traveling at 10% of the speed of light?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Time%20dilation',
#    'title': 'Time dilation - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': ' did the people of gibraltar vote to remain part of the united kingdom in the 2002 referendum?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Gibraltar',
#    'title': 'Gibraltar - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are nuts a type of fruit or a fastener?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Berry',
#    'title': 'Berry - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are phone socks still used by some people?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Sock',
#    'title': 'Sock - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are nuts a type of fruit or a fastener?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Fruit',
#    'title': 'Fruit - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'according to plato, what are the three types of people that society should be made up of?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/The%20Republic',
#    'title': 'The Republic - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are avocados considered a fruit or a vegetable in everyday speech?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Fruit',
#    'title': 'Fruit - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are nuts a type of fruit or a fastener?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/List%20of%20fruits',
#    'title': 'List of fruits - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are boys traditionally expected to be tougher than girls in many cultures?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Boy',
#    'title': 'Boy - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are a and b the same number?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Axiom',
#    'title': 'Axiom - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are any of the chemicals mentioned in the article used in the manufacturing process of soda glass?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Soda',
#    'title': 'Soda - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are nuts a type of fruit or a fastener?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Nut',
#    'title': 'Nut - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are there any countries where voting in elections is compulsory for citizens?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Election',
#    'title': 'Election - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are newts and salamanders closely related?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Newt',
#    'title': 'Newt - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are raspberries true berries?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Berry',
#    'title': 'Berry - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are the four points collinear?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Point%20%28geometry%29',
#    'title': 'Point (geometry) - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': ' which of these old communist parties no longer exists today?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/List%20of%20communist%20parties',
#    'title': 'List of communist parties - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are knives better than scissors for cutting through rope?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Scissors',
#    'title': 'Scissors - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are ferrets legal to have as pets in most places?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Ferret',
#    'title': 'Ferret - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are men more prone to developing osteoporosis than women?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Andrology',
#    'title': 'Andrology - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are animal by-products used in the production of non-human foods?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/By-product',
#    'title': 'By-product - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are albinic animals more likely to be attacked by predators than non-albino animals in the wild?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Albinism',
#    'title': 'Albinism - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are there any autobahns in germany where the speed limit is higher than 250 km/h?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Autobahn',
#    'title': 'Autobahn - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are galician and portuguese considered two dialects or two separate languages by most scholars?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Galician%20language',
#    'title': 'Galician language - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are seed plants that produce both male and female reproductive organs called monoecious or dioecious?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Fruit',
#    'title': 'Fruit - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are cults considered as deviant social movements in modern times?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Cult',
#    'title': 'Cult - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are seed plants that produce both male and female reproductive organs called monoecious or dioecious?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Female',
#    'title': 'Female - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'a patient has a terminal illness and wants to end their life, but their family members are opposed to it. how should the doctor handle this situation?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Medical%20ethics',
#    'title': 'Medical ethics - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are addition and multiplication dyadic functions?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Dyadic',
#    'title': 'Dyadic - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are strawberries true berries according to botanical definition?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Fruit',
#    'title': 'Fruit - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': ' which country uses the franc as its official currency?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Currency',
#    'title': 'Currency - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are hot dogs savoury or sweet?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Bun',
#    'title': 'Bun - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are strawberries true berries according to botanical definition?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Berry',
#    'title': 'Berry - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are there any duck species that live on antarctica?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Duck',
#    'title': 'Duck - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'after ten half-lives, what percentage of the original atoms remain?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Half-life%20%28element%29',
#    'title': 'Half-life (element) - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are blueberries a true berry or an aggregate fruit?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Fruit',
#    'title': 'Fruit - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are raspberries true berries?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Fruit',
#    'title': 'Fruit - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are the social sciences considered hard sciences?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Hard%20science',
#    'title': 'Hard science - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are blueberries a true berry or an aggregate fruit?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Berry',
#    'title': 'Berry - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are serbian, bosnian and croatian considered separate languages or a single language?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Slavs',
#    'title': 'Slavs - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are the colored ketchup products, ez squirt, still available in the market?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Ketchup',
#    'title': 'Ketchup - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are the 32 physical features of a buddha mentioned in the pāli canon exclusive to male buddhas, or can they also be found in female buddhas?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Buddha',
#    'title': 'Buddha - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': "are the manx's legs short?",
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Manx%20cat',
#    'title': 'Manx cat - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are pigs used for racing?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Pig',
#    'title': 'Pig - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are avocados considered a fruit or a vegetable in everyday speech?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/List%20of%20fruits',
#    'title': 'List of fruits - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are ready-tied bow ties more convenient than traditional bow ties?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Necktie',
#    'title': 'Necktie - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are snow leopards able to purr?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Snow%20leopard',
#    'title': 'Snow leopard - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are pseudorandom numbers generated by computer algorithms truly random?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Random',
#    'title': 'Random - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are golden retrievers good as guard dogs?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Golden%20Retriever',
#    'title': 'Golden Retriever - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}},
#  {'question': 'are coin purse compartments more common in europe than in other parts of the world?',
#   'metadata': {'source': 'https://simple.wikipedia.org/wiki/Wallet',
#    'title': 'Wallet - Simple English Wikipedia, the free encyclopedia',
#    'language': 'en'}}]

# %% [markdown]
# Let us filter out the duplicate responses.

# %%
# Process to only keep question and modified metadata.title
processed_qna = []
for entry in qna_asked_filtered:
    # Copy the question
    question = entry['question']

    # Extract and modify the title from the metadata
    title = entry['metadata']['title']
    # Remove the unwanted text from the title
    modified_title = title.replace(' - Simple English Wikipedia, the free encyclopedia', '')

    # Create a new dictionary with the modified content and add it to the new list
    processed_qna.append({'question': question, 'title': modified_title})
processed_qna
# Out:
# [{'question': 'are cassette tapes still popular among audiophiles?',
#   'title': 'Audio cassette'},
#  {'question': 'are handcuffs used for hog-tying a suspect?',
#   'title': 'Handcuffs'},
#  {'question': 'are there any cultures or belief systems that attribute supernatural powers to certain objects, such as amulets or talismans, as a form of fetishism?',
#   'title': 'Fetishism'},
#  {'question': 'are shelties considered to be highly energetic dogs?',
#   'title': 'Shetland Sheepdog'},
#  {'question': 'are biscuits in british english sweet or savory?',
#   'title': 'Biscuit'},
#  {'question': 'are midges and gnats the same thing?', 'title': 'Fly'},
#  {'question': 'approximately how many years will pass on earth for each year in the spaceship traveling at 10% of the speed of light?',
#   'title': 'Time dilation'},
#  {'question': ' did the people of gibraltar vote to remain part of the united kingdom in the 2002 referendum?',
#   'title': 'Gibraltar'},
#  {'question': 'are nuts a type of fruit or a fastener?', 'title': 'Berry'},
#  {'question': 'are phone socks still used by some people?', 'title': 'Sock'},
#  {'question': 'are nuts a type of fruit or a fastener?', 'title': 'Fruit'},
#  {'question': 'according to plato, what are the three types of people that society should be made up of?',
#   'title': 'The Republic'},
#  {'question': 'are avocados considered a fruit or a vegetable in everyday speech?',
#   'title': 'Fruit'},
#  {'question': 'are nuts a type of fruit or a fastener?',
#   'title': 'List of fruits'},
#  {'question': 'are boys traditionally expected to be tougher than girls in many cultures?',
#   'title': 'Boy'},
#  {'question': 'are a and b the same number?', 'title': 'Axiom'},
#  {'question': 'are any of the chemicals mentioned in the article used in the manufacturing process of soda glass?',
#   'title': 'Soda'},
#  {'question': 'are nuts a type of fruit or a fastener?', 'title': 'Nut'},
#  {'question': 'are there any countries where voting in elections is compulsory for citizens?',
#   'title': 'Election'},
#  {'question': 'are newts and salamanders closely related?', 'title': 'Newt'},
#  {'question': 'are raspberries true berries?', 'title': 'Berry'},
#  {'question': 'are the four points collinear?', 'title': 'Point (geometry)'},
#  {'question': ' which of these old communist parties no longer exists today?',
#   'title': 'List of communist parties'},
#  {'question': 'are knives better than scissors for cutting through rope?',
#   'title': 'Scissors'},
#  {'question': 'are ferrets legal to have as pets in most places?',
#   'title': 'Ferret'},
#  {'question': 'are men more prone to developing osteoporosis than women?',
#   'title': 'Andrology'},
#  {'question': 'are animal by-products used in the production of non-human foods?',
#   'title': 'By-product'},
#  {'question': 'are albinic animals more likely to be attacked by predators than non-albino animals in the wild?',
#   'title': 'Albinism'},
#  {'question': 'are there any autobahns in germany where the speed limit is higher than 250 km/h?',
#   'title': 'Autobahn'},
#  {'question': 'are galician and portuguese considered two dialects or two separate languages by most scholars?',
#   'title': 'Galician language'},
#  {'question': 'are seed plants that produce both male and female reproductive organs called monoecious or dioecious?',
#   'title': 'Fruit'},
#  {'question': 'are cults considered as deviant social movements in modern times?',
#   'title': 'Cult'},
#  {'question': 'are seed plants that produce both male and female reproductive organs called monoecious or dioecious?',
#   'title': 'Female'},
#  {'question': 'a patient has a terminal illness and wants to end their life, but their family members are opposed to it. how should the doctor handle this situation?',
#   'title': 'Medical ethics'},
#  {'question': 'are addition and multiplication dyadic functions?',
#   'title': 'Dyadic'},
#  {'question': 'are strawberries true berries according to botanical definition?',
#   'title': 'Fruit'},
#  {'question': ' which country uses the franc as its official currency?',
#   'title': 'Currency'},
#  {'question': 'are hot dogs savoury or sweet?', 'title': 'Bun'},
#  {'question': 'are strawberries true berries according to botanical definition?',
#   'title': 'Berry'},
#  {'question': 'are there any duck species that live on antarctica?',
#   'title': 'Duck'},
#  {'question': 'after ten half-lives, what percentage of the original atoms remain?',
#   'title': 'Half-life (element)'},
#  {'question': 'are blueberries a true berry or an aggregate fruit?',
#   'title': 'Fruit'},
#  {'question': 'are raspberries true berries?', 'title': 'Fruit'},
#  {'question': 'are the social sciences considered hard sciences?',
#   'title': 'Hard science'},
#  {'question': 'are blueberries a true berry or an aggregate fruit?',
#   'title': 'Berry'},
#  {'question': 'are serbian, bosnian and croatian considered separate languages or a single language?',
#   'title': 'Slavs'},
#  {'question': 'are the colored ketchup products, ez squirt, still available in the market?',
#   'title': 'Ketchup'},
#  {'question': 'are the 32 physical features of a buddha mentioned in the pāli canon exclusive to male buddhas, or can they also be found in female buddhas?',
#   'title': 'Buddha'},
#  {'question': "are the manx's legs short?", 'title': 'Manx cat'},
#  {'question': 'are pigs used for racing?', 'title': 'Pig'},
#  {'question': 'are avocados considered a fruit or a vegetable in everyday speech?',
#   'title': 'List of fruits'},
#  {'question': 'are ready-tied bow ties more convenient than traditional bow ties?',
#   'title': 'Necktie'},
#  {'question': 'are snow leopards able to purr?', 'title': 'Snow leopard'},
#  {'question': 'are pseudorandom numbers generated by computer algorithms truly random?',
#   'title': 'Random'},
#  {'question': 'are golden retrievers good as guard dogs?',
#   'title': 'Golden Retriever'},
#  {'question': 'are coin purse compartments more common in europe than in other parts of the world?',
#   'title': 'Wallet'}]

# %% [markdown]
# Let us count how many correct and incorrect matches our LLM model made.

# %%
matches = 0
mismatches = 0

validation_results = []

for index, row in qna.head(50).iterrows():
    question = row['question']
    article = row['article']

    # Find the corresponding entry in processed_qna based on the question
    corresponding_entry = next((item for item in processed_qna if item['question'] == question), None)

    # If a matching question is found in processed_qna
    if corresponding_entry:
        # Compare the article in qna with the title in processed_qna
        if corresponding_entry['title'] == article:
            matches += 1
            validation_results.append({'question': question, 'match': True})
        else:
            mismatches += 1
            validation_results.append({'question': question, 'match': False})
    else:
        # If no matching question is found, consider it a mismatch for tracking purposes
        mismatches += 1
        validation_results.append({'question': question, 'match': False})

print(f"Matches: {matches}, Mismatches: {mismatches}")
for result in validation_results:
    print(result)
# Out:
# Matches: 44, Mismatches: 6
# {'question': ' did the people of gibraltar vote to remain part of the united kingdom in the 2002 referendum?', 'match': True}
# {'question': ' which country uses the franc as its official currency?', 'match': True}
# {'question': ' which of these old communist parties no longer exists today?', 'match': True}
# {'question': 'a patient has a terminal illness and wants to end their life, but their family members are opposed to it. how should the doctor handle this situation?', 'match': True}
# {'question': 'according to plato, what are the three types of people that society should be made up of?', 'match': True}
# {'question': 'after ten half-lives, what percentage of the original atoms remain?', 'match': True}
# {'question': 'approximately how many years will pass on earth for each year in the spaceship traveling at 10% of the speed of light?', 'match': True}
# {'question': 'are a and b the same number?', 'match': True}
# {'question': 'are addition and multiplication dyadic functions?', 'match': True}
# {'question': 'are albinic animals more likely to be attacked by predators than non-albino animals in the wild?', 'match': True}
# {'question': 'are animal by-products used in the production of non-human foods?', 'match': True}
# {'question': 'are any of the chemicals mentioned in the article used in the manufacturing process of soda glass?', 'match': True}
# {'question': 'are avocados considered a fruit or a vegetable in everyday speech?', 'match': False}
# {'question': 'are biscuits in british english sweet or savory?', 'match': True}
# {'question': 'are blueberries a true berry or an aggregate fruit?', 'match': True}
# {'question': 'are boys traditionally expected to be tougher than girls in many cultures?', 'match': True}
# {'question': 'are cassette tapes still popular among audiophiles?', 'match': True}
# {'question': 'are coin purse compartments more common in europe than in other parts of the world?', 'match': True}
# {'question': 'are cults considered as deviant social movements in modern times?', 'match': True}
# {'question': 'are dogs considered mammals?', 'match': False}
# {'question': 'are ferrets legal to have as pets in most places?', 'match': True}
# {'question': 'are galician and portuguese considered two dialects or two separate languages by most scholars?', 'match': True}
# {'question': 'are golden retrievers good as guard dogs?', 'match': True}
# {'question': 'are handcuffs used for hog-tying a suspect?', 'match': True}
# {'question': 'are hot dogs savoury or sweet?', 'match': True}
# {'question': 'are knives better than scissors for cutting through rope?', 'match': True}
# {'question': 'are men more prone to developing osteoporosis than women?', 'match': True}
# {'question': 'are midges and gnats the same thing?', 'match': True}
# {'question': 'are newts and salamanders closely related?', 'match': True}
# {'question': 'are nuts a type of fruit or a fastener?', 'match': False}
# {'question': 'are phone socks still used by some people?', 'match': True}
# {'question': 'are pigs used for racing?', 'match': True}
# {'question': 'are pseudorandom numbers generated by computer algorithms truly random?', 'match': True}
# {'question': 'are raspberries true berries?', 'match': True}
# {'question': 'are ready-tied bow ties more convenient than traditional bow ties?', 'match': True}
# {'question': 'are seed plants that produce both male and female reproductive organs called monoecious or dioecious?', 'match': False}
# {'question': 'are serbian, bosnian and croatian considered separate languages or a single language?', 'match': True}
# {'question': 'are shelties considered to be highly energetic dogs?', 'match': True}
# {'question': 'are snow leopards able to purr?', 'match': True}
# {'question': 'are strawberries true berries according to botanical definition?', 'match': False}
# {'question': 'are the 32 physical features of a buddha mentioned in the pāli canon exclusive to male buddhas, or can they also be found in female buddhas?', 'match': True}
# {'question': 'are the colored ketchup products, ez squirt, still available in the market?', 'match': True}
# {'question': 'are the four points collinear?', 'match': True}
# {'question': "are the manx's legs short?", 'match': True}
# {'question': 'are the set of all fords and the set of all dodges equal?', 'match': False}
# {'question': 'are the social sciences considered hard sciences?', 'match': True}
# {'question': 'are there any autobahns in germany where the speed limit is higher than 250 km/h?', 'match': True}
# {'question': 'are there any countries where voting in elections is compulsory for citizens?', 'match': True}
# {'question': 'are there any cultures or belief systems that attribute supernatural powers to certain objects, such as amulets or talismans, as a form of fetishism?', 'match': True}
# {'question': 'are there any duck species that live on antarctica?', 'match': True}

# %% [markdown]
# The results are pretty good !

# %%
correct_questions = [result['question'] for result in validation_results if result['match']]
correct_points = qna[qna['question'].isin(correct_questions)]['points'].sum()

# Calculate the total available points from all questions considered (first 50 entries)
total_points = qna.head(50)['points'].sum()

# Calculate the accuracy ratio
accuracy_ratio = correct_points / total_points if total_points > 0 else 0

# Output the results
print(f"Total Correct Points: {correct_points}")
print(f"Total Available Points: {total_points}")
print(f"Accuracy Ratio: {accuracy_ratio:.2f}")
# Out:
# Total Correct Points: 2464
# Total Available Points: 2835
# Accuracy Ratio: 0.87

# %%
We also scored a lot of points !

# %%
validation_df = pd.DataFrame(validation_results)
processed_qna_df = pd.DataFrame(processed_qna)

# Merge validation results with processed_qna to include model's answers
validation_with_answers = pd.merge(validation_df, processed_qna_df, on='question', how='left')

# Rename columns in qna for clarity when merging
qna_renamed = qna.rename(columns={'article': 'correct_answer'})

# Merge the combined data with qna to get the correct answers and additional information
full_comparison = pd.merge(validation_with_answers, qna_renamed, on='question', how='left')

# Filter to show only the mismatches
incorrect_answers = full_comparison[full_comparison['match'] == False]

# Selecting relevant columns to display
incorrect_answers = incorrect_answers[['question', 'title', 'correct_answer', 'points', 'article_text']]

true_mismatches = full_comparison[(full_comparison['match'] == False) & (full_comparison['title'] != full_comparison['correct_answer'])]

# Selecting relevant columns to display
true_mismatches = true_mismatches[['question', 'title', 'correct_answer', 'points', 'article_text']]

# Display the DataFrame with true mismatches
true_mismatches
# Out:
#                                              question           title  \
# 12  are avocados considered a fruit or a vegetable...           Fruit
# 21                       are dogs considered mammals?             NaN
# 31            are nuts a type of fruit or a fastener?           Berry
# 32            are nuts a type of fruit or a fastener?           Fruit
# 33            are nuts a type of fruit or a fastener?  List of fruits
# 41  are seed plants that produce both male and fem...           Fruit
# 46  are strawberries true berries according to bot...           Fruit
# 52  are the set of all fords and the set of all do...             NaN
#
#     correct_answer  points                                       article_text
# 12  List of fruits      56  Fruits on this list are defined as the word is...
# 21            Fact      89  A fact is a statement that is real or true, or...
# 31             Nut      53  Nut or nuts can mean different things:\nNut (f...
# 32             Nut      53  Nut or nuts can mean different things:\nNut (f...
# 33             Nut      53  Nut or nuts can mean different things:\nNut (f...
# 41          Female      52  Female is a gender. It is the sex that produce...
# 46           Berry      45  The word berry is used for many different kind...
# 52             Set      76  A set is an idea from mathematics. A set has m...

# %% [markdown]
# Upon reviewing the questions that our model answered incorrectly, we observed common issues. Incorrect responses often arose when the model chose similar but incorrect documents or when it failed to retrieve relevant documents due to a search similarity threshold set at 0.3. Additionally, removing duplicate questions sometimes eliminated the possibility of correct answers. Future research could investigate the impact of including duplicate questions in the training set on model accuracy.
